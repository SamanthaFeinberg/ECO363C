# %% [markdown]
# # Computational Economics - ECO 363C (34880 & 34885)
# # Lecture 1
#
# ## Organization / Syllabus
# Note: The syllabus is subject to change throughout the semester as needed
#
# ### General Description
# __Instructor__:
#
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;Oliver Pfäuti\
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;__Email__: oliver.pfauti@austin.utexas.edu; &emsp;&nbsp;Office: BRB 3.118
#
# __Lectures__:
#
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;Monday and Wednesday 10:00 am-11:30 am in SZB 2.222 (**Section 34880**)\
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;Monday and Wednesday 02:30 pm-4:00 pm in WAG 420 (**Section 34885**)
#
# __Office Hours__: Wednesday 08:30 am to 09:30 am in BRB 3.118, or by appointment
#
# __Teaching Assistants__:
#
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;Shih-Hsuan (Daniel) Hsu\
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;__Email__: shsu@utexas.edu; &emsp;&emsp;&nbsp;Office Hours: Thursday from 01:00 pm to 02:00 pm in BRB 3.124
#
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;Priyansh Dhandha\
# &emsp;&nbsp;&nbsp;&emsp;&nbsp;&nbsp;__Email__: priyansh@utexas.edu;  &emsp;&nbsp;Office Hours: Monday from 12:00pm to 01:00 pm in BRB Lobby
#
#
#
#
# ### Course Description
# The purpose of this class is to introduce students to **computational economics**. We will use **Python** throughout the course and focus on **macroeconomic applications**, but the computational tools that we will cover can also be applied in other fields and disciplines. After an **introduction to Python** the course consists of two overarching main themes. The first is how we can use Python to do **macroeconomic data analysis** and applications cover empirical evidence on economic growth, business cycles, and income and wealth inequality. If time permits, we will also cover regression analysis. The second main theme covers how we can use Python to **solve macroeconomic models** that cannot be solved analytically but rather require a computer to solve them. Applications here include asset pricing, optimal consumption choices, and the role of expectations in macroeconomic models.
#
# ### Prerequisites
# This class is largely self-contained but students taking this course must have basic knowledge of Intermediate Microeconomics, Intermediate Macroeconomics, Introduction to Econometrics, **Linear Algebra, and Calculus. Knowledge of programming or Python is not required**.
#
# ### Lecture Format
# There are two identical sections of this course. The first section (Section 34880) will be in person on Mondays and Wednesdays from 10:00 am - 11:30 am in SZB 2.222. The second section (Section 34885) will be in person on Mondays and Wednesdays from 2:30 pm - 4:00 pm in WAG 420. The course will be conducted in person, in the traditional lecture format. Regular attendance is expected. There will be no class recordings.
#
#
# ### Course Website
# All instructions, assignments, readings, and essential information will be on the Canvas website at [https://utexas.instructure.com](https://utexas.instructure.com). I will also use the website to send general announcements. Check this site regularly and use it to ask questions about the course schedule. **This syllabus is subject to change; students who miss class are responsible for learning about any changes to the syllabus. I will consider posting information on Canvas as sufficient notice.**
#
# ### Problem Sets
# There will be **four problem sets**. It is encouraged to discuss and work together in groups of up to three students. However, **students must submit their own write-up of the solutions.**
#
# ### Exams
# There will be **one in-person midterm exam on Wednesday, March 12, 2025, during class**, and **one in-person final exam** on:
#
#  - **Section 34880: Thursday, May 1, 8:00 am-10:00 am**
#  - **Section 34885: Saturday, May 3, 7:00 pm-9:00 pm**
#
# The **final exam is cumulative**. It will cover all the material we discussed in the whole course. The final exam will take place in the **computer lab, and will be an open-book exam. The use of artificial intelligence (AI) is not allowed. Communication with others is not allowed.**
#
#
# There are no make-up midterm exams. In case a student misses the midterm exam (for whatever reason), the midterm’s weight will be shifted toward the final exam. The shift in weights only applies to students that did not take the midterm exam. The student may be excused from taking the final exam following standard procedures provided by the university—that is, by providing documentation of the reason for your missing the final exam, which might include a letter from the doctor for medical reasons or the dean of students for other reasons. If the student is so excused, a make-up exam will replace the final exam.
#
# ### Grading
# The **final grade** will be composed of a weighted average of the following components: **problem sets (40\%, 10\% per problem set), midterm exam (25\%), and final exam (35\%)**. I will use plus/minus grade categories when assigning final grades (i.e., A, A-, B+, B,..., D-, F). Final grades will be curved per department guidelines, meaning that your letter grade will be assigned based on your weighted average course score and your performance relative to the rest of the class. Please do not ask me about extra credit or extra work to improve your grade, as these are not available.
#
# If you would like any grade to be reconsidered, you have 5 days to submit a request once the assignment grades are released. The request must be written and must provide specific reasons why specific questions were graded improperly. Appeals submitted after the 5-day window will not be accepted. Keep in mind that revisions can lead to higher grades but also lower grades. I will not discuss the outcomes of the appeal.
#
#
#
#
#
# ### Class Material
# The main source of material for the class will be the **lecture notes and Jupyter Notebooks**, which I will post on the course’s Canvas website. A very good resource for using Python in Economics is [https://quantecon.org](https://quantecon.org). This site provides further background material and more advanced material going beyond the scope of this class. Another great source (mainly focusing on Data Analysis with Python) is the [online textbook](https://aeturrell.github.io/coding-for-economists/intro.html) by Turrel.
#
# ### Schedule
# The schedule is detailed below. The schedule contains the topics, the problem sets’ due dates, and the dates of the exams. Note: Specific material covered may differ somewhat from the outline depending on time, and we may ultimately go a little faster or slower than suggested by this schedule.
#
#
#  1. Introduction to Python and computational economics
#  2. Macroeconomic data analysis:
#      - The use of data in macroeconomics
#      - Doing data analysis in Python
#      - Pandas for panel data
#
# __Problem Set 1: Due on Wednesday, February 26, 2025, end of day.__
#
#  2. Macroeconomic data analysis (continued):
#       - Applications
#           - Economic Growth Evidence
#           - Business Cycles
#           - Income and Wealth Inequality
#
# __Midterm: Wednesday, March 12, 2025, during class.__
#
# __Problem Set 2: Due on Wednesday, March 26, 2025, end of day.__
#
#  3. Solving macroeconomic models with Python
#       - linear dynamics:
#            - present values
#            - consumption smoothing
#            - monetary policy
#            - aggregate demand and supply
#
# __Problem Set 3: Due on Wednesday, April 9, 2025, end of day.__
#
#  3. Solving macroeconomic models with Python (continued)
#       - Non-linear dynamics
#            - the Solow-Swan Growth Model
#            - The Cobweb Model and the role of expectations
#            - The Overlapping Generations Model
#
#
# __Problem Set 4: Due on Wednesday, April 23, 2025, end of day.__
#
# __Cumulative final exam:__
#
#  - Section 34880: Thursday, May 1, 8:00 am-10:00 am
#  - Section 34885: Saturday, May 3, 7:00 pm-9:00 pm
#
# ## Lecture 1: Getting Started
# ### What is Python?
#  - Python is a general-purpose programming language
#  - It's free and open source
#  - It experienced rapid adoption in the last decade and is now one of the most popular programming languages
#  ([here is some extra information on Python's popularity](https://pythoncircle.com/post/763/the-rising-popularity-of-python/))
#
# ### Why use Python?
# #### Strengths:
#  - very popular and widely used programming language
#  - free
#  - general purpose language $\to$ can be used for many different applications (_Python is the second best language at everything_)
#  - widely used in academia, the public sector, and industry
#  - easy syntax, beginner friendly
#  - many packages
#  - good online support / community
#
# #### Weaknesses:
#  - relatively slow (compared to C++ or Fortran)
#
#
# ### What is Python used for?
#  - communication
#  - web development
#  - CGI and graphical user interfaces
#  - game development
#  - data science
#  - academia (research in economics and many other fields)
#  - ...
#
#
# Python is used and supported extensively by, e.g., Google, Netflix, Meta, Dropbox, Amazon, Reddit, and many more...

# %% [markdown]
# In macroeconomics, Matlab used to be most common programming language. Nowadays, many macroeconomists are now switching to Python. We seem to be in good company:\
# ![python_vs_matlab.png](attachment:python_vs_matlab.png)
#
#
# (Picture was produced using Stack Overflow Trends)
#
# Similarly, people google *Python* much more often than *Matlab* or *Stata* and these differences have increased over recent years:
#
# ![Python_GoogleTrends.png](attachment:b41316f9-ea84-4c73-89f2-24eb2458eb70.png)
#
#
# (You can play around with this by clicking on this [link](https://trends.google.com/trends/explore?date=all&geo=US&q=%2Fm%2F05z1_,%2Fm%2F053_x,%2Fm%2F05ymvd&hl=en))

# %% [markdown]
# ### What is Python?
#
# What is nice about Python, is that its syntax will prove helpful in most other programming languages, too.
#
# Python is a [high-level language](https://en.wikipedia.org/wiki/High-level_programming_language) with a relatively small core language, supported by many packages and libraries (we will talk about this later in more detail).
#
# What is a high-level language? Let's ask ChatGPT:
#
#
# ![ChatGPT_HLL.png](attachment:b8987956-0606-4392-bbef-1db068a44870.png)

# %% [markdown]
# Note: The terms _Packages_ and _Libraries_ are often used interchangeably. To be precise, however, a _package_ is a collection of modules whereas a _library_ is a collection of packages.
# [Here](https://learnpython.com/blog/python-modules-packages-libraries-frameworks/) is a good blog post explaining some of Python's terminology like _modules_, _packages_, and _libraries_.
#
# There are multiple programming styles that Python supports:
#
#  - [procedural](https://en.wikipedia.org/wiki/Procedural_programming)
#  - [object-oriented](https://en.wikipedia.org/wiki/Object-oriented_programming)
#  - [functional](https://en.wikipedia.org/wiki/Functional_programming)
#
#  We will discuss these different styles as we go along.

# %% [markdown]
# ### Concepts
# #### Key elements of a computational environment for coding:
#
#  - operating system
#  - Python interpreter
#  - integrated development environment (IDE)
#  - packages

# %% [markdown]
# ### Operating system
# There are three (main) operating systems:
#
#  1. Windows
#  2. MacOS
#  3. Linux
#
# You can use whichever you prefer (I will be using MacOS). Many cloud services use Linux. You can use whatever you're most familiar with.

# %% [markdown]
# ### Python interpreter
# For a computer to be able to read and execute Python code, you will need to get a Python interpreter installed on your computer. There are many ways to do this. I recommend using the _Anaconda distribution_ of Python because it is very flexible and simple. We talk about installing Python later.

# %% [markdown]
# ### IDE
# An integrated development environment (IDE) is a software application that provides a few tools to make coding easier. The most important of these is a way to write the code itself. IDEs are not the only way to program, but they are perhaps the most useful. If you know, for example, Stata or Matlab, these packages up the language and the IDE together. But they are actually separate things: the language is a way of processing your instructions, the IDE is where you write these instructions.
#
# You can use whatever IDE you want. I recommend using __Microsoft's Visual Studio Code__, which runs on all major operating systems and is very popular. There are many others out there (e.g. PyCharm).
# Among other things, __VS Code__ provides:
#
#  - a way to run your code interactively (line-by-line) or all at once
#  - a way to debug your code
#  - a quick way to access helpful information about commonly used software packages
#  - automatic code formatting, so that your code follows best practice guidelines
#  - auto-completion of your code when you hit __TAB__
#  - automatic code checking for basic errors
#  - colouring your brackets in pairs so you can keep track of the logical order of execution of your code
#
# In this course, I will use something called __Jupyter Notebook__ ([here is a way to use Jupyter Notebook without having to install anything](https://jupyter.org/try)). Jupyter Notebook is not a full-featured IDE but it has many advantages that makes it very well suited for learning Python and for teaching it:
#
#  - it basically looks like lecture notes (it can be exported to a variety of formats, including .html and .pdf)
#  - this makes it easy to share with others
#  - code can be executed directly in the notebook and live in class
#  - you can download the notebook files and directly write your notes in it while in class
#  - you can change the code or the examples the way you want
#
#
# In a way, Jupyter notebooks strike a balance between simple text editors, which are fast to start and simple and easy to manipulate, and IDE’s which tend to start slower and be feature-rich and complex. Simple text editors typically can only edit code, and cannot run the code. A full IDE can edit code, run the code, debug code, provide syntax highlighting and context help.
#
# In the context of problem-solving, Jupyter notebooks are quite handy. Jupyter notebooks open quickly and quickly produce output. Data exploration, data cleaning, and plot building are accomplished in Jupyter notebooks easier and quicker than in a text editor or an IDE.
#
# In the context of sharing solutions to problems, Jupyter notebooks are also useful. Markdown cells render text in different sizes, bold and italic. Tables and images, plots and code can all be shown together in the same Jupyter notebook.
#
# We will talk about how to install and use Jupyter Notebook later.

# %% [markdown]
# ### Packages / Libraries
# A Python package is a collection of functions, data, and documentation that extends the capabilities of an installed version of Python. Using packages is key to most data science because most of the functionality we’ll need comes from extra packages. You’ll see statements like ```import numpy as np``` at the start of many Python code scripts. These are instructions to use an installed package (here one called ```numpy```) and to give it a shortened name (```np```, for convenience) in the rest of the script. The functions in the numpy package are then accessed through syntax like ```np.```; for example, you can take logs with ```np.log(x)``` where ```x``` is a variable containing a number. You only need to install packages once, but you must import them into each script you need to use them in.

# %% [markdown]
# ### Typical workflow
#
# The typical workflow for analysis with code might be something like this:
#
#  - Launch Jupyter Notebook or open up your integrated development environment (IDE)
#  - Write some code in a script (a text file with code in)
#  - If necessary for the analysis that you’re doing, install any extra packages
#  - Send bits of code from the script, or the entire script, to be executed by Python and add-on packages, and to display results
#
# There are two main ways to achieve this workflow:
#
# 1. Installing an IDE (or Jupyter Notebook), Python, and any extra packages on your own computer
# 2. Using a computer in the cloud that you access through your internet browser. The cloud computer has an IDE and Python built-in, and you can easily install extra packages in it too. We recommend to use Python in the cloud only for the first one or two lectures. Basically, until you installed Anaconda (as discussed at the end of this lecture).
#
# But ultimately, you should pick whichever you’re more comfortable with! Eventually, you’ll probably try both.

# %% [markdown]
# ## Python in the Cloud
# Let's try Python in the cloud, so everybody can run some code.
# Using Python in the cloud basically means that we use a remote server that already has Python installed.
#
# Probably the most reliable one right now is [Google Colab](https://colab.research.google.com).
#
# There is a free version you can use for the rest of today's lecture and replicate what I am doing.
#
# Here are a few tutorials for how to use Google Colab:
#
#  - [Google colab tutorial](https://colab.research.google.com/drive/16pBJQePbqkz3QFV54L4NIkOn1kwpuRrj)
#  - [Google Colab Tutorial for Beginners](https://pub.towardsai.net/google-colab-tutorial-for-beginners-834595494d44)
#  - [Intro to Google Colab](https://levelup.gitconnected.com/google-colab-what-is-it-how-to-use-it-and-why-should-i-care-721bb8a88c90)
#
# To use Google Colab you need to be logged in to a Google account. If you don't have one, there are other ways to use Python in the cloud. I explain one below the next two images.

# %% [markdown]
# When you click on the [Google Colab link](https://colab.research.google.com) (which is https://colab.research.google.com), you should see something like this:
# ![GoogleColab_Screenshot.png](attachment:GoogleColab_Screenshot.png)

# %% [markdown]
# Click on __+ New Notebook__ on the bottom left.
# You should then see something like this:
#
# ![Google_Colab_Screenshot.png](attachment:9fdd6b80-6b95-4790-9132-f8bebd546345.png)
#
# You are now ready to go and write your first Python commands! (The AI assistant is new and I encourage you to try it out as this is likely the future of coding. But bear in mind that you won't be allowed to use it in the final exam!)
#
# You can also directly work in _this_ notebook. For this, click on __Upload__ and upload the notebook _Computational Economics - Lecture 1.ipynb_ which you can download on this course's Canvas site. I also encourage you to do this because then you will have the lecture material as well as your notes all in the same place and you will be allowed to bring these (annotated) notebooks to the final exam, so you can also copy-paste code snippets directly from the notes to your final exam solution.

# %% [markdown]
# ***Another possibility*** is to use [Jupyter Lite](https://jupyter.org/try-jupyter/lab/) (link: https://jupyter.org/try-jupyter/lab/), where you should see something like this:
#
# ![Jupyter_Lite_Screenshot.png](attachment:938ea847-a402-46fe-8769-46f348d5bb77.png)
#
# (Last year's final exam was on Jupyter Lite, and it is very likely that it will be again this year. So, familiarize yourself with it.)
#
# Click on the icon on the top left (under **Notebook** where it says **Python (Pyodide)**. You should be ready to go then. You can also upload Jupyter Notebooks in Jupyter Lite.

# %% [markdown]
# ## A quick glance at some packages
# ### Numerical Programming
# A key package that we will use over and over again is ```NumPy```(see [here](https://numpy.org) for details)
#
# NumPy provides the basic array data type plus some simple processing operations

# %%
# let's build some arrays (it is ok if you don't understand everything here... we will discuss all the details later):
import numpy as np # load the library

a = np.linspace(-np.pi, np.pi, 100) # this creates an even grid from -π to π
b = np.cos(a) # apply the cosine function to each element of the grid a
c = np.sin(a) # apply sin to each element of a

# %% [markdown]
# Let's take the inner product

# %%
b @ c
# Out:
# 8.767360422479055e-16

# %% [markdown]
# The number you see here might vary slightly but it's practically zero.

# %% [markdown]
# The [SciPy](https://scipy.org) library is built on top of NumPy and provides additional functionality.
# For example, let's calculate $\int_{-2}^2 \phi(z)dz$ where $\phi$ is the standard normal densitiy.

# %%
from scipy.stats import norm
from scipy.integrate import quad

ϕ = norm()
value, error = quad(ϕ.pdf, -2, 2) # integrate using Gaussian quadrature
value
# Out:
# 0.9544997361036417

# %% [markdown]
# SciPy includes many of the standard routines used in
#
#  - linear algebra
#  - integration
#  - interpolation
#  - optimization
#  - distributions and statistical techniques

# %% [markdown]
# ## Graphics / Data Visualization
# We will talk about data visualizations and graphics in much more detail later. But let's just see an example of what other people have done using Python. See [here](https://matplotlib.org/stable/gallery/index.html) for many cool examples.
#
# Later in this course, we will code exactly this figure step by step.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import wbgapi as wb
import pandas_datareader.data as web

# Set graphical parameters
cycler = plt.cycler(linestyle=['-', '-.', '--', ':'], 
        color=['#377eb8', '#ff7f00', '#4daf4a', '#ff334f'])
plt.rc('axes', prop_cycle=cycler)


def plot_series(data, country, ylabel, 
                txt_pos, ax, g_params,
                b_params, t_params, ylim=15, baseline=0):
    """
    Plots a time series with recessions highlighted. 

    Parameters
    ----------
    data : pd.DataFrame
        Data to plot
    country : str
        Name of the country to plot
    ylabel : str
        Label of the y-axis
    txt_pos : float
        Position of the recession labels
    y_lim : float
        Limit of the y-axis
    ax : matplotlib.axes._subplots.AxesSubplot
        Axes to plot on
    g_params : dict
        Parameters for the line
    b_params : dict
        Parameters for the recession highlights
    t_params : dict
        Parameters for the recession labels
    baseline : float, optional
        Dashed baseline on the plot, by default 0
    
    Returns
    -------
    ax : matplotlib.axes.Axes
        Axes with the plot.
    """

    ax.plot(data.loc[country], label=country, **g_params)
    
    # Highlight recessions
    ax.axvspan(1973, 1975, **b_params)
    ax.axvspan(1990, 1992, **b_params)
    ax.axvspan(2007, 2009, **b_params)
    ax.axvspan(2019, 2021, **b_params)
    
    if ylim != None:
        ax.set_ylim([-ylim, ylim])
    else:
        ylim = ax.get_ylim()[1]
    ax.text(1974, ylim + ylim*txt_pos,
            'Oil Crisis\n(1974)', **t_params) 
    ax.text(1991, ylim + ylim*txt_pos,
            '1990s recession\n(1991)', **t_params) 
    ax.text(2008, ylim + ylim*txt_pos,
            'GFC\n(2008)', **t_params) 
    ax.text(2020, ylim + ylim*txt_pos,
            'Covid-19\n(2020)', **t_params)

    # Add a baseline for reference
    if baseline != None:
        ax.axhline(y=baseline, 
                   color='black', 
                   linestyle='--')
    ax.set_ylabel(ylabel)
    ax.legend()
    return ax

# Define graphical parameters 
g_params = {'alpha': 0.7}
b_params = {'color':'grey', 'alpha': 0.2}
t_params = {'color':'grey', 'fontsize': 9, 
            'va':'center', 'ha':'center'}


start_date = datetime.datetime(1978, 1, 1)
end_date = datetime.datetime(2024, 12, 31)

# Limit the plot to a specific range
start_date_graph = datetime.datetime(1977, 1, 1)
end_date_graph = datetime.datetime(2024, 12, 31)

nber = web.DataReader('USREC', 'fred', start_date, end_date)
consumer_confidence = web.DataReader('UMCSENT', 'fred', 
                                start_date, end_date)


fig, ax = plt.subplots()
ax.plot(consumer_confidence, **g_params, 
        color='#377eb8', linestyle='-', 
        linewidth=2)
ax.fill_between(nber.index, 0, 1, 
            where=nber['USREC']==1, 
            color='grey', edgecolor='none',
            alpha=0.3, 
            transform=ax.get_xaxis_transform(), 
            label='NBER recession indicators')
ax.set_ylim([0, ax.get_ylim()[1]])
ax.set_ylabel('consumer sentiment index')

# Plot CPI on another y-axis
ax_t = ax.twinx()
inflation = web.DataReader('CPILFESL', 'fred', 
                start_date, end_date).pct_change(12)*100

# Add CPI on the legend without drawing the line again
ax_t.plot(2020, 0, **g_params, linestyle='-', 
          linewidth=2, label='consumer sentiment index')
ax_t.plot(inflation, **g_params, 
          color='#ff7f00', linestyle='--', 
          linewidth=2, label='CPI YoY change (%)')

ax_t.fill_between(nber.index, 0, 1,
                  where=nber['USREC']==1, 
                  color='grey', edgecolor='none',
                  alpha=0.3, 
                  transform=ax.get_xaxis_transform(), 
                  label='NBER recession indicators')
ax_t.set_ylim([0, ax_t.get_ylim()[1]])
ax_t.set_xlim([start_date_graph, end_date_graph])
ax_t.legend(loc='upper center',
            bbox_to_anchor=(0.5, 1.1),
            ncol=3, fontsize=9)
ax_t.set_ylabel('CPI YoY change (%)')
plt.show()

# %% [markdown]
# ## Symbolic Algebra
# You can use the Python library [SymPy](https://www.sympy.org/en/index.html) to help you with solving equations.

# %%
from sympy import Symbol

x, y = Symbol('x'), Symbol('y') # here, we tell Python to treat 'x' and 'y' as algebraic symbols

x + x + x + y
# Out:
# 3*x + y

# %%
# We can do more difficult stuff:
expression = (x+y)**2
expression.expand()
# Out:
# x**2 + 2*x*y + y**2

# %%
# We can even find roots of polynomials
from sympy import solve
solve(x**2 - x -6)
# Out:
# [-2, 3]

# %%
# You can even solve without explicitly specifying the parameter values: 
x, a, b, c = Symbol('x'), Symbol('a'), Symbol('b'), Symbol('c')
solve(a*x**2 + b*x + c, x) # does the answer look familiar?
# Out:
# [(-b - sqrt(-4*a*c + b**2))/(2*a), (-b + sqrt(-4*a*c + b**2))/(2*a)]

# %%
# We can even calculate derivates, limits, integrals, etc etc
from sympy import limit, diff, integrate, log

limit(1/x, x, 0)
# Out:
# oo

# %%
diff(37*x**2 - 1/x + log(3*x), x)
# Out:
# 74*x + 1/x + x**(-2)

# %%
integrate(log(x)*x, x)
# Out:
# x**2*log(x)/2 - x**2/4

# %% [markdown]
# We can check whether this is correct by taking the derivative:

# %%
diff(x**2*log(x)/2-x**2/4,x)
# Out:
# x*log(x)

# %% [markdown]
# Symbolic Algebra is very useful not just because it helps us with our math problem sets but also because we can easily create tables of derivatives, generate LaTeX output, etc.

# %% [markdown]
# ## Statistics
# One of the most popular libraries for working with data is [pandas](https://pandas.pydata.org). Pandas is fast, efficient, flexible and well designed. Let's see an example.

# %%
import pandas as pd
np.random.seed(78712)

data = np.random.rand(5,2) # 5x2 matrix of U(0,1) random draws
dates = pd.date_range('2010-12-28', periods =5) #, freq = 'M')

df = pd.DataFrame(data, columns=('price','weight'), index=dates)
print(df)
# Out:
#                price    weight
# 2010-12-28  0.731329  0.253862
# 2010-12-29  0.114664  0.843217
# 2010-12-30  0.696436  0.617165
# 2010-12-31  0.600600  0.080138
# 2011-01-01  0.739171  0.428813

# %%
df.mean()
# Out:
# price     0.576440
# weight    0.444639
# dtype: float64

# %% [markdown]
# We can also add other variables, include more observations, etc. We will cover all of this more extensively during the next few weeks.

# %%
data = np.random.rand(20,3) # 20x3 matrix of U(0,1) random draws
dates = pd.date_range('2010-12-28', periods =20)

df = pd.DataFrame(data, columns=('price','weight','height'), index=dates)
print(df)
# Out:
#                price    weight    height
# 2010-12-28  0.044393  0.672362  0.860489
# 2010-12-29  0.957176  0.927202  0.694230
# 2010-12-30  0.151211  0.367079  0.290869
# 2010-12-31  0.257284  0.050450  0.276268
# 2011-01-01  0.172751  0.474869  0.370943
# 2011-01-02  0.335914  0.791577  0.638093
# 2011-01-03  0.676362  0.065658  0.909682
# 2011-01-04  0.349753  0.106627  0.976321
# 2011-01-05  0.879856  0.634388  0.172169
# 2011-01-06  0.585223  0.486268  0.598082
# 2011-01-07  0.916862  0.353436  0.578116
# 2011-01-08  0.533812  0.491388  0.189808
# 2011-01-09  0.682215  0.998889  0.594908
# 2011-01-10  0.572359  0.128659  0.914754
# 2011-01-11  0.870443  0.355730  0.912767
# 2011-01-12  0.684643  0.031523  0.783188
# 2011-01-13  0.917948  0.384374  0.997940
# 2011-01-14  0.719287  0.974171  0.808608
# 2011-01-15  0.368295  0.220433  0.751525
# 2011-01-16  0.426883  0.700348  0.491984

# %%
df.mean()
# Out:
# price     0.555133
# weight    0.460772
# height    0.640537
# dtype: float64

# %% [markdown]
# # Homework and Additional Material
#
# Before the next lecture, please install:
#
#  - __Anaconda__
#
# To do so, simply click "Download" [on this link](https://www.anaconda.com/download) (the link is: https://www.anaconda.com/download) and follow the installation instructions. If you are asked whether you want to make Anaconda your default Python installation, say yes.
#
# [Here](https://www.youtube.com/watch?v=ZWQwGR5ppnk&list=PLdH4Y6nsHMAx6bvTaCFZxG2depbdKgpjh) is a video explaining how to install Anaconda.
#
# Additional material on getting started with Python is [here](https://cs50.harvard.edu/python/2022/weeks/0/). This is an OpenCourseWare _Introduction to Programming with Python_. We will not cover everything taught in that course (plus, we will talk about many things that are not covered in the OpenCourseWare class), but it might still be useful to get started with Python.
#
# [Here](https://egallic.fr/Enseignement/Python/en/_main.pdf) is a link to a textbook **Python for economists** by Ewen Gallic. It provides additional information of similar concepts that we are discussing in class. But there is a lot in the class that the book does not cover and the book is also already 5 years old, which can be a long time when it comes to coding. But if you are looking for additional material, check it out.
#
# A very good resource is this [collection of Jupyter Notebooks](https://gist.github.com/ocoyawale/54d92fd4bf92508a2a6e482b5fa480fd#introductory-tutorials), including Tutorials and many more interesting stuff. We will discuss Jupyter Notebook soon!
